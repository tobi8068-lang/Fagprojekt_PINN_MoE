# %%
import torch
import time

device = torch.device("cuda")

x = torch.randn(10000, 10000, device=device)

start = time.time()
y = x @ x
torch.cuda.synchronize()
print("GPU time:", time.time() - start)
# Out:
# GPU time: 0.46435022354125977

# %%
device = torch.device("cuda")

x = torch.randn(10000, 10000)

start = time.time()
y = x @ x
torch.cuda.synchronize()
print("GPU time:", time.time() - start)
# Out:
# GPU time: 2.5927841663360596
